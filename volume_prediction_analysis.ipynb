# %% [markdown]
# # Tree Growth and Yield Analysis

# %% [markdown]
# ### Import all the necessary libraries

# %%
import numpy as np # this for specific mathematical functions such pi, random, etc.
import pandas as pd  # this for read data and to create dataframes
import matplotlib.pyplot as plt # this for visualization of data

import pyodbc # this is to connect to external database (eg. SQL, MS Access, etc)

# %%
# LOAD THE DATASET
def connect_to_database(conn, db_driver, db_path):
    conn = conn.connect(
        rf"DRIVER={db_driver};"
        rf"DBQ={db_path};"
    )
    return conn, conn.cursor()

file_path = r"C:\Users\GILBERT FG\Desktop\Readings\PSP_database.accdb"
ms_access_driver = r"Microsoft Access Driver (*.mdb, *.accdb)"

conn, db = connect_to_database(pyodbc, ms_access_driver, file_path)

# list all tables
for table in db.tables(tableType="TABLE"):
    print(table.table_name)
# Out:
# Block register
# Plot monitoring history
# Plot-block relation
# PSPs
# Slope correction factors
# Thinning history
# TreeData

# %% [markdown]
# ### Query the database to select the dataset for teak in Tain II plantation

# %%
query = "SELECT * FROM TreeData WHERE AreaType = 'Teak' AND Plantations = 'Tain II'"
teak_df = pd.read_sql(query, conn)
teak_df.head()
# Out:
# C:\Users\GILBERT FG\AppData\Local\Temp\ipykernel_3920\1647123111.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   teak_df = pd.read_sql(query, conn)
#   Plantations AreaType  Monitoring year  Monitoring month  Monitoring day  \
# 0     Tain II     Teak           2018.0               1.0              13
# 1     Tain II     Teak           2018.0               1.0              13
# 2     Tain II     Teak           2018.0               1.0              13
# 3     Tain II     Teak           2018.0               1.0              13
# 4     Tain II     Teak           2018.0               1.0              13
#
#   PLOT  TREE NR Tree SPECIES Species scientific name  H (m)  DBH (cm)  \
# 0    1     71.0         Teak         Tectona grandis   7.25      12.0
# 1    1     76.0         Teak         Tectona grandis   8.25      12.0
# 2    1     68.0         Teak         Tectona grandis   7.00      11.8
# 3    1     53.0         Teak         Tectona grandis   7.25      11.5
# 4    1     58.0         Teak         Tectona grandis   7.00      10.5
#
#   Merchantable height (m)     REMARKS  Incorrect DBH  Incorrect H  \
# 0                    None  Fire scars          False        False
# 1                    None  Fire scars          False        False
# 2                    None  Fire scars          False        False
# 3                    None  Fire scars          False        False
# 4                    None  Fire scars          False        False
#
#   Incorrect H / DBH  Exclude Justification for exclusion
# 0              None    False                        None
# 1              None    False                        None
# 2              None    False                        None
# 3              None    False                        None
# 4              None    False                        None

# %%
teak_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191860 entries, 0 to 191859
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Plantations                  191860 non-null  object
#  1   AreaType                     191860 non-null  object
#  2   Monitoring year              191860 non-null  float64
#  3   Monitoring month             191860 non-null  float64
#  4   Monitoring day               191860 non-null  int64
#  5   PLOT                         191860 non-null  object
#  6   TREE NR                      191860 non-null  float64
#  7   Tree SPECIES                 191860 non-null  object
#  8   Species scientific name      191851 non-null  object
#  9   H (m)                        191804 non-null  float64
#  10  DBH (cm)                     191800 non-null  float64
#  11  Merchantable height (m)      0 non-null       object
#  12  REMARKS                      70254 non-null   object
#  13  Incorrect DBH                191860 non-null  bool
#  14  Incorrect H                  191860 non-null  bool
#  15  Incorrect H / DBH            0 non-null       object
#  16  Exclude                      191860 non-null  bool
#  17  Justification for exclusion  53601 non-null   object
# dtypes: bool(3), float64(5), int64(1), object(9)
# memory usage: 22.5+ MB

# %%
teak_df.rename(columns={'PLOT': 'Plot no'}, inplace=True)

# %%
teak_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191860 entries, 0 to 191859
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Plantations                  191860 non-null  object
#  1   AreaType                     191860 non-null  object
#  2   Monitoring year              191860 non-null  float64
#  3   Monitoring month             191860 non-null  float64
#  4   Monitoring day               191860 non-null  int64
#  5   Plot no                      191860 non-null  object
#  6   TREE NR                      191860 non-null  float64
#  7   Tree SPECIES                 191860 non-null  object
#  8   Species scientific name      191851 non-null  object
#  9   H (m)                        191804 non-null  float64
#  10  DBH (cm)                     191800 non-null  float64
#  11  Merchantable height (m)      0 non-null       object
#  12  REMARKS                      70254 non-null   object
#  13  Incorrect DBH                191860 non-null  bool
#  14  Incorrect H                  191860 non-null  bool
#  15  Incorrect H / DBH            0 non-null       object
#  16  Exclude                      191860 non-null  bool
#  17  Justification for exclusion  53601 non-null   object
#  18  Age (years)                  191860 non-null  float64
# dtypes: bool(3), float64(6), int64(1), object(9)
# memory usage: 24.0+ MB

# %%
teak_df_trim = teak_df[['Plantations', 'AreaType', 'Monitoring year', 'Plot no', 'H (m)', 'DBH (cm)']]
teak_df_trim.head()
# Out:
#   Plantations AreaType  Monitoring year Plot no  H (m)  DBH (cm)
# 0     Tain II     Teak           2018.0       1   7.25      12.0
# 1     Tain II     Teak           2018.0       1   8.25      12.0
# 2     Tain II     Teak           2018.0       1   7.00      11.8
# 3     Tain II     Teak           2018.0       1   7.25      11.5
# 4     Tain II     Teak           2018.0       1   7.00      10.5

# %%
query = "SELECT * FROM [Plot-block relation] WHERE AreaType = 'Teak' AND Plantations = 'Tain II'"
plt_blk_df = pd.read_sql(query, conn)
plt_blk_df.head()
# Out:
# C:\Users\GILBERT FG\AppData\Local\Temp\ipykernel_3920\1246043612.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   plt_blk_df = pd.read_sql(query, conn)
#    RelationID Plantations Plot no AreaType  Deviating plant year Block  \
# 0          74     Tain II    1370     Teak                   NaN  PF80
# 1          76     Tain II    1372     Teak                   NaN   C17
# 2          77     Tain II    1366     Teak                   NaN   C17
# 3          78     Tain II    1363     Teak                   NaN   C17
# 4          79     Tain II    1374     Teak                   NaN   C17
#
#   Start date             End date
# 0 2020-05-01  9999-12-31 00:00:00
# 1 2020-05-01  9999-12-31 00:00:00
# 2 2020-05-01  9999-12-31 00:00:00
# 3 2020-05-01  9999-12-31 00:00:00
# 4 2020-05-01  9999-12-31 00:00:00

# %%
plt_blk_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1111 entries, 0 to 1110
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   RelationID            1111 non-null   int64
#  1   Plantations           1111 non-null   object
#  2   Plot no               1111 non-null   object
#  3   AreaType              1111 non-null   object
#  4   Deviating plant year  7 non-null      float64
#  5   Block                 1111 non-null   object
#  6   Start date            1111 non-null   datetime64[ns]
#  7   End date              1111 non-null   object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(5)
# memory usage: 69.6+ KB

# %%
plt_blk_df_trim = plt_blk_df[['Plantations', 'Plot no', 'AreaType', 'Block']]
plt_blk_df_trim.head()
# Out:
#   Plantations Plot no AreaType Block
# 0     Tain II    1370     Teak  PF80
# 1     Tain II    1372     Teak   C17
# 2     Tain II    1366     Teak   C17
# 3     Tain II    1363     Teak   C17
# 4     Tain II    1374     Teak   C17

# %%
query = "SELECT * FROM [Block register] WHERE Plantation = 'Tain II'"
block_register_df = pd.read_sql(query, conn)
block_register_df.head()
# Out:
# C:\Users\GILBERT FG\AppData\Local\Temp\ipykernel_3920\2907982518.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   block_register_df = pd.read_sql(query, conn)
#   PLANTATION BLOCK   STATUS ROTATION   OWNERSHIP  RESERVE  YEAR PLANTED  \
# 0    Tain II   A17  PLANTED        1  FORM GHANA  TAIN II          2023
# 1    Tain II   A19  PLANTED        1  FORM GHANA  TAIN II          2019
# 2    Tain II   A20  PLANTED        1  FORM GHANA  TAIN II          2019
# 3    Tain II   A21  PLANTED        1  FORM GHANA  TAIN II          2019
# 4    Tain II   A22  PLANTED        1  FORM GHANA  TAIN II          2019
#
#    BLOCK AREA (ha)  PRODUCTIVE  UNPRODUCTIVE       TEAK  NATURAL INDIGENOUS  \
# 0        61.957130   58.858151           NaN  58.858151                 NaN
# 1        67.587663   64.984407          0.15  64.984407                 NaN
# 2        70.331435   70.197867          0.00  70.197867                 NaN
# 3        48.657170   47.743954          0.40  47.743954                 NaN
# 4        50.624752   50.110498          0.00  50.110498                 NaN
#
#    PLANTED INDIGENOUS  GMELINA  OPEN LAND      ROCK REMARK
# 0                 NaN      NaN        NaN  3.098979   None
# 1                 NaN      NaN        0.0  2.453256   None
# 2                 NaN      NaN        0.0  0.133569   None
# 3                 NaN      NaN        0.0  0.513216   None
# 4                 NaN      NaN        0.0  0.514254   None

# %%
block_register_df_trim = block_register_df[['PLANTATION', 'BLOCK', 'YEAR PLANTED', 'PRODUCTIVE']]
block_register_df_trim.head()
# Out:
#   PLANTATION BLOCK  YEAR PLANTED  PRODUCTIVE
# 0    Tain II   A17          2023   58.858151
# 1    Tain II   A19          2019   64.984407
# 2    Tain II   A20          2019   70.197867
# 3    Tain II   A21          2019   47.743954
# 4    Tain II   A22          2019   50.110498

# %%
block_register_df_trim.rename(columns={'BLOCK': 'Block'}, inplace=True)
block_register_df_trim.rename(columns={'PLANTATION': 'Plantations'}, inplace=True)
block_register_df_trim.head()
# Out:
# C:\Users\GILBERT FG\AppData\Local\Temp\ipykernel_3920\2255623193.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   block_register_df_trim.rename(columns={'BLOCK': 'Block'}, inplace=True)
# C:\Users\GILBERT FG\AppData\Local\Temp\ipykernel_3920\2255623193.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   block_register_df_trim.rename(columns={'PLANTATION': 'Plantations'}, inplace=True)
#   Plantations Block  YEAR PLANTED  PRODUCTIVE
# 0     Tain II   A17          2023   58.858151
# 1     Tain II   A19          2019   64.984407
# 2     Tain II   A20          2019   70.197867
# 3     Tain II   A21          2019   47.743954
# 4     Tain II   A22          2019   50.110498

# %%
teak_blk_merge = pd.merge(teak_df_trim, plt_blk_df_trim, on=['Plot no', 'Plantations', 'AreaType'], how='outer')

# %%
teak_blk_merge.head()
# Out:
#   Plantations AreaType  Monitoring year Plot no  H (m)  DBH (cm) Block
# 0     Tain II     Teak           2018.0       1   7.25      12.0   B39
# 1     Tain II     Teak           2018.0       1   8.25      12.0   B39
# 2     Tain II     Teak           2018.0       1   7.00      11.8   B39
# 3     Tain II     Teak           2018.0       1   7.25      11.5   B39
# 4     Tain II     Teak           2018.0       1   7.00      10.5   B39

# %%
result_df = pd.merge(teak_blk_merge, block_register_df_trim, on=['Plantations', 'Block'], how='outer')
result_df.head()
# Out:
#   Plantations AreaType  Monitoring year Plot no  H (m)  DBH (cm) Block  \
# 0     Tain II      NaN              NaN     NaN    NaN       NaN   A17
# 1     Tain II     Teak           2023.0    1141   4.00       5.2   A19
# 2     Tain II     Teak           2023.0    1141   4.25       5.5   A19
# 3     Tain II     Teak           2023.0    1141   3.75       3.7   A19
# 4     Tain II     Teak           2023.0    1141   3.50       3.2   A19
#
#    YEAR PLANTED  PRODUCTIVE
# 0        2023.0   58.858151
# 1        2019.0   64.984407
# 2        2019.0   64.984407
# 3        2019.0   64.984407
# 4        2019.0   64.984407

# %%
result_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191903 entries, 0 to 191902
# Data columns (total 9 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Plantations      191903 non-null  object
#  1   AreaType         191860 non-null  object
#  2   Monitoring year  191860 non-null  float64
#  3   Plot no          191860 non-null  object
#  4   H (m)            191804 non-null  float64
#  5   DBH (cm)         191800 non-null  float64
#  6   Block            191646 non-null  object
#  7   YEAR PLANTED     191608 non-null  float64
#  8   PRODUCTIVE       191608 non-null  float64
# dtypes: float64(5), object(4)
# memory usage: 13.2+ MB

# %%
result_df.dropna()
# Out:
#        Plantations AreaType  Monitoring year Plot no  H (m)  DBH (cm) Block  \
# 1          Tain II     Teak           2023.0    1141   4.00       5.2   A19
# 2          Tain II     Teak           2023.0    1141   4.25       5.5   A19
# 3          Tain II     Teak           2023.0    1141   3.75       3.7   A19
# 4          Tain II     Teak           2023.0    1141   3.50       3.2   A19
# 5          Tain II     Teak           2023.0    1141   4.50       5.5   A19
# ...            ...      ...              ...     ...    ...       ...   ...
# 191641     Tain II     Teak           2023.0    1370   4.00       5.5  PF80
# 191642     Tain II     Teak           2023.0    1370   4.25       5.8  PF80
# 191643     Tain II     Teak           2023.0    1370   2.00       2.0  PF80
# 191644     Tain II     Teak           2023.0    1370   5.25       6.7  PF80
# 191645     Tain II     Teak           2023.0    1370   5.00       6.5  PF80
#
#         YEAR PLANTED  PRODUCTIVE
# 1             2019.0   64.984407
# 2             2019.0   64.984407
# 3             2019.0   64.984407
# 4             2019.0   64.984407
# 5             2019.0   64.984407
# ...              ...         ...
# 191641        2020.0  115.368242
# 191642        2020.0  115.368242
# 191643        2020.0  115.368242
# 191644        2020.0  115.368242
# 191645        2020.0  115.368242
#
# [191504 rows x 9 columns]

# %%
result_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191903 entries, 0 to 191902
# Data columns (total 9 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Plantations      191903 non-null  object
#  1   AreaType         191860 non-null  object
#  2   Monitoring year  191860 non-null  float64
#  3   Plot no          191860 non-null  object
#  4   H (m)            191804 non-null  float64
#  5   DBH (cm)         191800 non-null  float64
#  6   Block            191646 non-null  object
#  7   YEAR PLANTED     191608 non-null  float64
#  8   PRODUCTIVE       191608 non-null  float64
# dtypes: float64(5), object(4)
# memory usage: 13.2+ MB

# %%
result_df['Age (years)'] = result_df['Monitoring year'] - result_df['YEAR PLANTED']
result_df.head()
# Out:
#   Plantations AreaType  Monitoring year Plot no  H (m)  DBH (cm) Block  \
# 0     Tain II      NaN              NaN     NaN    NaN       NaN   A17
# 1     Tain II     Teak           2023.0    1141   4.00       5.2   A19
# 2     Tain II     Teak           2023.0    1141   4.25       5.5   A19
# 3     Tain II     Teak           2023.0    1141   3.75       3.7   A19
# 4     Tain II     Teak           2023.0    1141   3.50       3.2   A19
#
#    YEAR PLANTED  PRODUCTIVE  Age (years)
# 0        2023.0   58.858151          NaN
# 1        2019.0   64.984407          4.0
# 2        2019.0   64.984407          4.0
# 3        2019.0   64.984407          4.0
# 4        2019.0   64.984407          4.0

# %%
result_df.dropna(subset=['Plot no'], inplace=True)

# %%
result_df.head()
# Out:
#   Plantations AreaType  Monitoring year Plot no  H (m)  DBH (cm) Block  \
# 1     Tain II     Teak           2023.0    1141   4.00       5.2   A19
# 2     Tain II     Teak           2023.0    1141   4.25       5.5   A19
# 3     Tain II     Teak           2023.0    1141   3.75       3.7   A19
# 4     Tain II     Teak           2023.0    1141   3.50       3.2   A19
# 5     Tain II     Teak           2023.0    1141   4.50       5.5   A19
#
#    YEAR PLANTED  PRODUCTIVE  Age (years)
# 1        2019.0   64.984407          4.0
# 2        2019.0   64.984407          4.0
# 3        2019.0   64.984407          4.0
# 4        2019.0   64.984407          4.0
# 5        2019.0   64.984407          4.0

# %%
result_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 191860 entries, 1 to 191902
# Data columns (total 10 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Plantations      191860 non-null  object
#  1   AreaType         191860 non-null  object
#  2   Monitoring year  191860 non-null  float64
#  3   Plot no          191860 non-null  object
#  4   H (m)            191804 non-null  float64
#  5   DBH (cm)         191800 non-null  float64
#  6   Block            191603 non-null  object
#  7   YEAR PLANTED     191565 non-null  float64
#  8   PRODUCTIVE       191565 non-null  float64
#  9   Age (years)      191565 non-null  float64
# dtypes: float64(6), object(4)
# memory usage: 16.1+ MB

# %%
result_df['Age (years)'].dropna()
# Out:
# 1         4.0
# 2         4.0
# 3         4.0
# 4         4.0
# 5         4.0
#          ...
# 191641    3.0
# 191642    3.0
# 191643    3.0
# 191644    3.0
# 191645    3.0
# Name: Age (years), Length: 191565, dtype: float64

# %%
result_df.isnull()
# Out:
#         Plantations  AreaType  Monitoring year  Plot no  H (m)  DBH (cm)  \
# 1             False     False            False    False  False     False
# 2             False     False            False    False  False     False
# 3             False     False            False    False  False     False
# 4             False     False            False    False  False     False
# 5             False     False            False    False  False     False
# ...             ...       ...              ...      ...    ...       ...
# 191898        False     False            False    False  False     False
# 191899        False     False            False    False  False     False
# 191900        False     False            False    False  False     False
# 191901        False     False            False    False  False     False
# 191902        False     False            False    False  False     False
#
#         Block  YEAR PLANTED  PRODUCTIVE  Age (years)
# 1       False         False       False        False
# 2       False         False       False        False
# 3       False         False       False        False
# 4       False         False       False        False
# 5       False         False       False        False
# ...       ...           ...         ...          ...
# 191898   True          True        True         True
# 191899   True          True        True         True
# 191900   True          True        True         True
# 191901   True          True        True         True
# 191902   True          True        True         True
#
# [191860 rows x 10 columns]

# %% [markdown]
# #### Predicting future DBH, Height and Volume base on age using regression models

# %% [markdown]
# #### Chapman-Richards growth function

# %%
# Define the chapman-richards growth function
def chapman_richards(age, a, b, c):
    return a * (1 - np.exp(-b*age))**c

# Logistic growth function
def logistic(age, Hmax, k, t0):
    return Hmax / (1 + np.exp(-k * (age-t0)))

# %%
from scipy.optimize import curve_fit

# %%
# Fit model to DBH vs Age
proj_dbh, _ = curve_fit(chapman_richards, result_df['Age (years)'], result_df['DBH (cm)'], p0=[30, 0.05, 1.5])
result_df['Height_Pred'] = chapman_richards(result_df['Age (years)', *proj_dbh])

result_df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[108], line 2
#       1 # Fit model to DBH vs Age
# ----> 2 proj_dbh, _ = curve_fit(chapman_richards, result_df['Age (years)'], result_df['DBH (cm)'], p0=[30, 0.05, 1.5])
#       3 result_df['Height_Pred'] = chapman_richards(result_df['Age (years)', *proj_dbh])
#       5 result_df.head()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\optimize\_minpack_py.py:930, in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, full_output, nan_policy, **kwargs)
#     928 # optimization may produce garbage for float32 inputs, cast them to float64
#     929 if check_finite:
# --> 930     ydata = np.asarray_chkfinite(ydata, float)
#     931 else:
#     932     ydata = np.asarray(ydata, float)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_function_base_impl.py:646, in asarray_chkfinite(a, dtype, order)
#     644 a = asarray(a, dtype=dtype, order=order)
#     645 if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
# --> 646     raise ValueError(
#     647         "array must not contain infs or NaNs")
#     648 return a
#
# ValueError: array must not contain infs or NaNs
